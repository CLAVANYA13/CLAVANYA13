# %%
#Step 1: Initialize Slope and Intercept
#Step 2: Initialize Learning Rate and Iterations
#Step 3: Use for loop till end of iteration value
#Step 4: Calculate Y_pred = m*X+c
#Step 5: Using Partial Differential Calculus, arrive at differential values of slope and intercept
#         PD_Slope = (-2/n) * sum(X * (Y - Y_pred))
#        PD_Intercept = (-2/n) * sum(Y - Y_pred)
#Step 6: Then multiply these differential values with the learning rate and subtract it from previous slope and intercept values
#         in order to get new slope and intercept values
#Step 7 : Now, print the new slope and intercept values

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Laxminarayen/Inceptez-Batch-17/main/Day%205%20Linear%20Regression%20Hands%20on/data.csv")

# %%
df
# Out:
#     32.502345269453031  31.70700584656992
# 0            53.426804          68.777596
# 1            61.530358          62.562382
# 2            47.475640          71.546632
# 3            59.813208          87.230925
# 4            55.142188          78.211518
# ..                 ...                ...
# 94           50.030174          81.536991
# 95           49.239765          72.111832
# 96           50.039576          85.232007
# 97           48.149859          66.224958
# 98           25.128485          53.454394
#
# [99 rows x 2 columns]

# %%
X = df.iloc[:,0]
Y = df.iloc[:,1]
plt.scatter(X,Y)

# %%
#Initialize slope(m),intercept(c),learning rate(lr),iterations(iter)

m = 0
c = 0
lr = 0.0001
iter_ = 1000

# %%
#Lets have a look at the line when slope and intercept is 0
Y_pred1 = m*X+c
plt.scatter(X,Y)
plt.plot([min(X),max(X)],[min(Y_pred1),max(Y_pred1)],color='orange')

# %%
n = float(len(X))
print ("N values is",n)
for i in range(iter_):
    Y_pred2 = m*X + c
    PD_m = (-2/n) * sum(X * (Y - Y_pred2))
    PD_c = (-2/n) * sum(Y - Y_pred2)
    m = m - (lr * PD_m)
    c = c - (lr * PD_c)
    print("Iteration :",i+1)
    print("Slope :",m)
    print("Intercept :",c)
    
print("Final Slope & Intercept value:",m,c)
# Out:
# N values is 99.0
# Iteration : 1
# Slope : 0.7424335285415493
# Intercept : 0.014629895049539552
# Iteration : 2
# Slope : 1.1126970531564835
# Intercept : 0.02196251949501772
# Iteration : 3
# Slope : 1.2973530613136097
# Intercept : 0.02565587059950957
# Iteration : 4
# Slope : 1.3894434413943608
# Intercept : 0.027534253868739502
# Iteration : 5
# Slope : 1.4353697670003447
# Intercept : 0.028507481513835913
# Iteration : 6
# Slope : 1.4582732927875135
# Intercept : 0.02902929237235795
# Iteration : 7
# Slope : 1.4696949563897819
# Intercept : 0.029325973726661497
# Iteration : 8
# Slope : 1.4753904198682661
# Intercept : 0.02951037889658117
# Iteration : 9
# Slope : 1.478230129872329
# Intercept : 0.029638789753839184
# Iteration : 10
# Slope : 1.4796456270100444
# Intercept : 0.02973927502595998
# Iteration : 11
# Slope : 1.4803508449519853
# Intercept : 0.029825833065180055
# Iteration : 12
# Slope : 1.4807018345730651
# Intercept : 0.029905445088057748
# Iteration : 13
# ...

# %%
plt.scatter(X,Y)
plt.plot([min(X),max(X)],[min(Y_pred2),max(Y_pred2)],color='green')

# %%
plt.scatter(X,Y)
plt.plot([min(X),max(X)],[min(Y_pred1),max(Y_pred1)],color='red')
plt.plot([min(X),max(X)],[min(Y_pred2),max(Y_pred2)],color='green')

# %% [markdown]
# ## Red line is the Best fit line. Green line is the Gradient Descent arrived using for loop
